# %%
# !export ROS_MASTER_URI=http://10.0.25.81:11311

# %%
import sys
sys.path.append("/home/ubuntu/projects/ros/catkin_ws/devel/lib/python3/dist-packages")

# %%
from niryo_one_python_api.niryo_one_api import *
import rospy

# %%
rospy.get_param_names()
# Out:
# ['/run_id',
#  '/niryo_one_follow_joint_trajectory_controller/joints',
#  '/niryo_one_follow_joint_trajectory_controller/stop_trajectory_duration',
#  '/niryo_one_follow_joint_trajectory_controller/type',
#  '/niryo_one_follow_joint_trajectory_controller/state_publish_rate',
#  '/niryo_one_follow_joint_trajectory_controller/constraints/goal_time',
#  '/niryo_one_follow_joint_trajectory_controller/constraints/stopped_velocity_tolerance',
#  '/niryo_one_follow_joint_trajectory_controller/constraints/joint_6/trajectory',
#  '/niryo_one_follow_joint_trajectory_controller/constraints/joint_6/goal',
#  '/niryo_one_follow_joint_trajectory_controller/constraints/joint_4/trajectory',
#  '/niryo_one_follow_joint_trajectory_controller/constraints/joint_4/goal',
#  '/niryo_one_follow_joint_trajectory_controller/constraints/joint_5/trajectory',
#  '/niryo_one_follow_joint_trajectory_controller/constraints/joint_5/goal',
# ...

# %%
n = NiryoOne()

# %%
node = rospy.init_node("testnodeforniryo")

# %%
try:
    # Your code here
except NiryoOneException as e:
    print e
    # Handle errors here

# %%
x = n.get_joints()

# %%
x[3] += 0.01

# %%
n.move_pose(0, 0, 0.2, 0, 0, 0)
# Out:
# ---------------------------------------------------------------------------
# NiryoOneException                         Traceback (most recent call last)
# <ipython-input-8-a470974e503f> in <module>
# ----> 1 n.move_pose(0, 0, 0.2, 0, 0, 0)
#
# ~/projects/ros/catkin_ws/src/niryo_one_ros/niryo_one_python_api/src/niryo_one_python_api/niryo_one_api.py in move_pose(self, x, y, z, roll, pitch, yaw)
#     365             goal.cmd.rpy.pitch = pitch
#     366             goal.cmd.rpy.yaw = yaw
# --> 367             return self.execute_action('niryo_one/commander/robot_action', RobotMoveAction, goal)
#     368
#     369         def shift_pose(self, axis, value):
#
# ~/projects/ros/catkin_ws/src/niryo_one_ros/niryo_one_python_api/src/niryo_one_python_api/niryo_one_api.py in execute_action(self, action_name, action_msg_type, goal)
#     240             # Connect to server
#     241             if not client.wait_for_server(rospy.Duration(self.action_connection_timeout)):
# ...

# %%
rostop
